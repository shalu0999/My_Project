# %%
#Virtual_Mouse_project:--
#The system makes use of well-known python libraries like MediaPipe for real-time-tracking of hands and finger movements.

# %%
import cv2

# %%
# !pip install opencv-contrib-python
# Out:
# Requirement already satisfied: opencv-contrib-python in c:\users\pradeep yadav\ranjana1\lib\site-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\pradeep yadav\ranjana1\lib\site-packages (from opencv-contrib-python) (1.23.5)

# %%
pip install Mediapipe
# Out:
# Requirement already satisfied: Mediapipe in c:\users\pradeep yadav\ranjana1\lib\site-packages (0.10.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: protobuf<4,>=3.11 in c:\users\pradeep yadav\ranjana1\lib\site-packages (from Mediapipe) (3.20.3)
# Requirement already satisfied: opencv-contrib-python in c:\users\pradeep yadav\ranjana1\lib\site-packages (from Mediapipe) (4.7.0.72)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\pradeep yadav\ranjana1\lib\site-packages (from Mediapipe) (22.1.0)
# Requirement already satisfied: absl-py in c:\users\pradeep yadav\ranjana1\lib\site-packages (from Mediapipe) (1.4.0)
# Requirement already satisfied: numpy in c:\users\pradeep yadav\ranjana1\lib\site-packages (from Mediapipe) (1.23.5)
# Requirement already satisfied: matplotlib in c:\users\pradeep yadav\ranjana1\lib\site-packages (from Mediapipe) (3.7.0)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\pradeep yadav\ranjana1\lib\site-packages (from Mediapipe) (0.4.6)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\pradeep yadav\ranjana1\lib\site-packages (from Mediapipe) (23.5.26)
# Requirement already satisfied: CFFI>=1.0 in c:\users\pradeep yadav\ranjana1\lib\site-packages (from sounddevice>=0.4.4->Mediapipe) (1.15.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\pradeep yadav\ranjana1\lib\site-packages (from matplotlib->Mediapipe) (1.0.5)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pradeep yadav\ranjana1\lib\site-packages (from matplotlib->Mediapipe) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\pradeep yadav\ranjana1\lib\site-packages (from matplotlib->Mediapipe) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\pradeep yadav\ranjana1\lib\site-packages (from matplotlib->Mediapipe) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\pradeep yadav\ranjana1\lib\site-packages (from matplotlib->Mediapipe) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\pradeep yadav\ranjana1\lib\site-packages (from matplotlib->Mediapipe) (22.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\pradeep yadav\ranjana1\lib\site-packages (from matplotlib->Mediapipe) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\pradeep yadav\ranjana1\lib\site-packages (from matplotlib->Mediapipe) (9.4.0)
# Requirement already satisfied: pycparser in c:\users\pradeep yadav\ranjana1\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->Mediapipe) (2.21)
# Requirement already satisfied: six>=1.5 in c:\users\pradeep yadav\ranjana1\lib\site-packages (from python-dateutil>=2.7->matplotlib->Mediapipe) (1.16.0)

# %%
pip install pyautogui
# Out:
# Requirement already satisfied: pyautogui in c:\users\pradeep yadav\ranjana1\lib\site-packages (0.9.54)
# Requirement already satisfied: pygetwindow>=0.0.5 in c:\users\pradeep yadav\ranjana1\lib\site-packages (from pyautogui) (0.0.9)
# Requirement already satisfied: pyscreeze>=0.1.21 in c:\users\pradeep yadav\ranjana1\lib\site-packages (from pyautogui) (0.1.29)
# Requirement already satisfied: pymsgbox in c:\users\pradeep yadav\ranjana1\lib\site-packages (from pyautogui) (1.0.9)
# Requirement already satisfied: mouseinfo in c:\users\pradeep yadav\ranjana1\lib\site-packages (from pyautogui) (0.1.3)
# Requirement already satisfied: pytweening>=1.0.4 in c:\users\pradeep yadav\ranjana1\lib\site-packages (from pyautogui) (1.0.7)
# Requirement already satisfied: pyrect in c:\users\pradeep yadav\ranjana1\lib\site-packages (from pygetwindow>=0.0.5->pyautogui) (0.2.0)
# Requirement already satisfied: pyscreenshot in c:\users\pradeep yadav\ranjana1\lib\site-packages (from pyscreeze>=0.1.21->pyautogui) (3.1)
# Requirement already satisfied: Pillow>=9.2.0 in c:\users\pradeep yadav\ranjana1\lib\site-packages (from pyscreeze>=0.1.21->pyautogui) (9.4.0)
# Requirement already satisfied: pyperclip in c:\users\pradeep yadav\ranjana1\lib\site-packages (from mouseinfo->pyautogui) (1.8.2)
# Requirement already satisfied: entrypoint2 in c:\users\pradeep yadav\ranjana1\lib\site-packages (from pyscreenshot->pyscreeze>=0.1.21->pyautogui) (1.1)
# Requirement already satisfied: mss in c:\users\pradeep yadav\ranjana1\lib\site-packages (from pyscreenshot->pyscreeze>=0.1.21->pyautogui) (9.0.1)
# Requirement already satisfied: EasyProcess in c:\users\pradeep yadav\ranjana1\lib\site-packages (from pyscreenshot->pyscreeze>=0.1.21->pyautogui) (1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import mediapipe as mp
import pyautogui

cap = cv2.VideoCapture(0)
hand_detector = mp.solutions.hands.Hands()
drawing_utils = mp.solutions.drawing_utils
screen_width, screen_height = pyautogui.size()
index_y = 0
while True:
    _, frame = cap.read()
    frame = cv2.flip(frame, 1)
    frame_height, frame_width, _ = frame.shape
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    output = hand_detector.process(rgb_frame)
    hands = output.multi_hand_landmarks
    if hands:
        for hand in hands:
            drawing_utils.draw_landmarks(frame, hand)
            landmarks = hand.landmark
            for id, landmark in enumerate(landmarks):
                x = int(landmark.x*frame_width)
                y = int(landmark.y*frame_height)
                if id == 8:
                    cv2.circle(img=frame, center=(x,y), radius=10, color=(0, 255, 255))
                    
                    index_x = screen_width/frame_width*x
                    index_y = screen_height/frame_height*y

                if id == 4:
                    cv2.circle(img=frame, center=(x,y), radius=10, color=(0, 255, 255))
                    thumb_x = screen_width/frame_width*x
                    thumb_y = screen_height/frame_height*y
                    print('outside', abs(index_y - thumb_y))
                    if abs(index_y - thumb_y) < 20:
                        pyautogui.click()
                        pyautogui.sleep(1)
                    elif abs(index_y - thumb_y) < 100:
                        pyautogui.moveTo(index_x, index_y)
    cv2.imshow('Virtual Mouse', frame)
    cv2.waitKey(1)
# Out:
# outside 661.5
# outside 56.25
# outside 58.5
# outside 51.75
# outside 54.0
# outside 54.0
# outside 51.75
# outside 51.75
# outside 54.0
# outside 54.0
# outside 49.5
# outside 47.25
# outside 47.25
# outside 47.25
# outside 45.0
# outside 47.25
# outside 51.75
# outside 47.25
# outside 47.25
# outside 11.25
# outside 211.5
# outside 229.5
# outside 220.5
# outside 218.25
# outside 213.75
# outside 209.25
# outside 211.5
# outside 211.5
# outside 193.5
# outside 211.5
# outside 209.25
# outside 195.75
# outside 234.0
# outside 236.25
# outside 220.5
# outside 263.25
# outside 211.5
# outside 200.25
# outside 240.75
# outside 200.25
# outside 193.5
# outside 189.0
# outside 193.5
# outside 200.25
# outside 204.75
# outside 182.25
# outside 182.25
# outside 182.25
# outside 177.75
# outside 175.5
# outside 177.75
# outside 168.75
# outside 168.75
# outside 168.75
# outside 164.25
# outside 168.75
# outside 168.75
# outside 168.75
# outside 168.75
# outside 166.5
# outside 168.75
# outside 168.75
# outside 168.75
# outside 168.75
# outside 168.75
# outside 168.75
# outside 168.75
# outside 168.75
# outside 164.25
# outside 168.75
# outside 166.5
# outside 166.5
# outside 168.75
# outside 166.5
# outside 168.75
# outside 168.75
# outside 168.75
# outside 168.75
# outside 166.5
# outside 166.5
# outside 166.5
# outside 168.75
# outside 168.75
# outside 168.75
# outside 166.5
# outside 168.75
# outside 166.5
# outside 164.25
# outside 166.5
# outside 168.75
# outside 168.75
# outside 166.5
# outside 166.5
# outside 166.5
# outside 168.75
# outside 168.75
# outside 168.75
# outside 168.75
# outside 168.75
# outside 168.75
# outside 168.75
# outside 166.5
# outside 166.5
# outside 168.75
# outside 168.75
# outside 171.0
# outside 168.75
# outside 171.0
# outside 171.0
# outside 171.0
# outside 171.0
# outside 171.0
# outside 171.0
# outside 171.0
# outside 168.75
# outside 171.0
# outside 168.75
# outside 168.75
# outside 166.5
# outside 168.75
# outside 166.5
# outside 166.5
# outside 166.5
# outside 168.75
# outside 6.75
# outside 360.0
# outside 171.0
# outside 144.0
# outside 139.5
# outside 137.25
# outside 139.5
# outside 139.5
# outside 137.25
# outside 137.25
# outside 135.0
# outside 135.0
# outside 135.0
# outside 137.25
# outside 139.5
# outside 141.75
# outside 141.75
# outside 137.25
# outside 137.25
# outside 139.5
# outside 137.25
# outside 137.25
# outside 137.25
# outside 139.5
# outside 141.75
# outside 139.5
# outside 139.5
# outside 141.75
# outside 141.75
# outside 141.75
# outside 141.75
# outside 141.75
# outside 141.75
# outside 139.5
# outside 141.75
# outside 139.5
# outside 141.75
# outside 139.5
# outside 137.25
# outside 137.25
# outside 137.25
# outside 137.25
# outside 137.25
# outside 139.5
# outside 141.75
# outside 139.5
# outside 139.5
# outside 137.25
# outside 137.25
# outside 135.0
# outside 137.25
# outside 137.25
# outside 139.5
# outside 139.5
# outside 139.5
# outside 139.5
# outside 139.5
# outside 141.75
# outside 139.5
# outside 139.5
# outside 139.5
# outside 139.5
# outside 141.75
# outside 141.75
# outside 144.0
# outside 146.25
# outside 150.75
# outside 150.75
# outside 146.25
# outside 148.5
# outside 148.5
# outside 148.5
# outside 146.25
# outside 146.25
# outside 144.0
# outside 144.0
# outside 141.75
# outside 146.25
# outside 144.0
# outside 141.75
# outside 144.0
# outside 146.25
# outside 141.75
# outside 146.25
# outside 144.0
# outside 146.25
# outside 148.5
# outside 148.5
# outside 144.0
# outside 144.0
# outside 141.75
# outside 144.0
# outside 141.75
# outside 146.25
# outside 144.0
# outside 146.25
# outside 146.25
# outside 144.0
# outside 144.0
# outside 141.75
# outside 141.75
# outside 141.75
# outside 139.5
# outside 144.0
# outside 144.0
# outside 141.75
# outside 141.75
# outside 144.0
# outside 144.0
# outside 130.5
# outside 130.5
# outside 130.5
# outside 132.75
# outside 117.0
# outside 96.75
# outside 76.5
# outside 51.75
# outside 38.25
# outside 38.25
# outside 49.5
# outside 42.75
# outside 40.5
# outside 40.5
# outside 69.75
# outside 173.25
# outside 200.25
# outside 207.0
# outside 209.25
# outside 209.25
# outside 216.0
# outside 213.75
# outside 213.75
# outside 209.25
# outside 209.25
# outside 211.5
# outside 211.5
# outside 198.0
# outside 200.25
# outside 189.0
# outside 191.25
# outside 195.75
# outside 202.5
# outside 231.75
# outside 225.0
# outside 216.0
# outside 198.0
# outside 204.75
# outside 191.25
# outside 189.0
# outside 204.75
# outside 195.75
# outside 193.5
# outside 204.75
# outside 198.0
# outside 209.25
# outside 209.25
# outside 202.5
# outside 195.75
# outside 191.25
# outside 200.25
# outside 202.5
# outside 216.0
# outside 200.25
# outside 204.75
# outside 218.25
# outside 213.75
# outside 220.5
# outside 207.0
# outside 200.25
# outside 200.25
# outside 202.5
# outside 204.75
# outside 200.25
# outside 195.75
# outside 204.75
# outside 220.5
# outside 213.75
# outside 227.25
# outside 220.5
# outside 216.0
# outside 211.5
# outside 211.5
# outside 216.0
# outside 209.25
# outside 211.5
# outside 211.5
# outside 209.25
# outside 168.75
# outside 150.75
# outside 146.25
# outside 96.75
# outside 60.75
# outside 63.0
# outside 58.5
# outside 45.0
# outside 69.75
# outside 105.75
# outside 153.0
# outside 78.75
# outside 27.0
# outside 105.75
# outside 90.0
# outside 47.25
# outside 40.5
# outside 15.75
# outside 76.5
# outside 108.0
# outside 114.75
# outside 121.5
# outside 36.0
# outside 38.25
# outside 117.0
# outside 123.75
# outside 99.0
# outside 92.25
# outside 94.5
# outside 99.0
# outside 90.0
# outside 36.0
# outside 105.75
# outside 72.0
# outside 65.25
# outside 2.25
# outside 24.75
# outside 168.75
# outside 220.5
# outside 216.0
# outside 211.5
# outside 209.25
# outside 204.75
# outside 204.75
# outside 204.75
# outside 202.5
# outside 202.5
# outside 204.75
# outside 204.75
# outside 209.25
# outside 207.0
# outside 209.25
# outside 204.75
# outside 209.25
# outside 209.25
# outside 207.0
# outside 209.25
# outside 209.25
# outside 209.25
# outside 207.0
# outside 202.5
# outside 204.75
# outside 204.75
# outside 202.5
# outside 204.75
# outside 207.0
# outside 204.75
# outside 204.75
# outside 204.75
# outside 204.75
# outside 202.5
# outside 202.5
# outside 202.5
# outside 204.75
# outside 204.75
# outside 207.0
# outside 200.25
# outside 202.5
# outside 204.75
# outside 204.75
# outside 204.75
# outside 202.5
# outside 207.0
# outside 207.0
# outside 209.25
# outside 204.75
# outside 204.75
# outside 213.75
# outside 211.5
# outside 213.75
# outside 218.25
# outside 220.5
# outside 218.25
# outside 218.25
# outside 225.0
# outside 216.0
# outside 218.25
# outside 198.0
# outside 213.75
# outside 207.0
# outside 209.25
# outside 195.75
# outside 213.75
# outside 227.25
# outside 204.75
# outside 209.25
# outside 218.25
# outside 234.0
# outside 238.5
# outside 245.25
# outside 231.75
# outside 202.5
# outside 186.75
# outside 168.75
# outside 126.0
# outside 94.5
# outside 69.75
# outside 110.25
# outside 128.25
# outside 135.0
# outside 148.5
# outside 150.75
# outside 153.0
# outside 157.5
# outside 157.5
# outside 159.75
# outside 153.0
# outside 150.75
# outside 139.5
# outside 144.0
# outside 121.5
# outside 108.0
# outside 96.75
# outside 60.75
# outside 60.75
# outside 155.25
# outside 157.5
# outside 180.0
# outside 184.5
# outside 166.5
# outside 175.5
# outside 166.5
# outside 144.0
# outside 99.0
# outside 58.5
# outside 51.75
# outside 63.0
# outside 54.0
# outside 76.5
# outside 51.75
# outside 126.0
# outside 139.5
# outside 155.25
# outside 150.75
# outside 153.0
# outside 155.25
# outside 157.5
# outside 171.0
# outside 164.25
# outside 168.75
# outside 114.75
# outside 171.0
# outside 148.5
# outside 171.0
# outside 171.0
# outside 144.0
# outside 144.0
# outside 123.75
# outside 117.0
# outside 137.25
# outside 139.5
# outside 141.75
# outside 132.75
# outside 130.5
# outside 123.75
# outside 114.75
# outside 108.0
# outside 103.5
# outside 94.5
# outside 74.25
# outside 56.25
# outside 92.25
# outside 47.25
# outside 51.75
# outside 110.25
# outside 146.25
# outside 144.0
# outside 150.75
# outside 137.25
# outside 159.75
# outside 171.0
# outside 173.25
# outside 186.75
# outside 193.5
# outside 200.25
# outside 198.0
# outside 202.5
# outside 207.0
# outside 211.5
# outside 216.0
# outside 222.75
# outside 225.0
# outside 227.25
# outside 227.25
# outside 225.0
# outside 222.75
# outside 220.5
# outside 220.5
# outside 211.5
# outside 216.0
# outside 211.5
# outside 211.5
# outside 213.75
# outside 213.75
# outside 211.5
# outside 211.5
# outside 211.5
# outside 211.5
# outside 213.75
# outside 216.0
# outside 218.25
# outside 218.25
# outside 218.25
# outside 209.25
# outside 191.25
# outside 193.5
# outside 171.0
# outside 144.0
# outside 146.25
# outside 139.5
# outside 146.25
# outside 146.25
# outside 141.75
# outside 132.75
# outside 137.25
# outside 114.75
# outside 96.75
# outside 83.25
# outside 74.25
# outside 78.75
# outside 87.75
# outside 92.25
# outside 101.25
# outside 47.25
# outside 47.25
# outside 49.5
# outside 49.5
# outside 51.75
# outside 51.75
# outside 69.75
# outside 148.5
# outside 184.5
# outside 200.25
# outside 191.25
# outside 195.75
# outside 186.75
# outside 184.5
# outside 189.0
# outside 184.5
# outside 191.25
# outside 186.75
# outside 189.0
# outside 189.0
# outside 186.75
# outside 186.75
# outside 189.0
# outside 193.5
# outside 195.75
# outside 195.75
# outside 198.0
# outside 198.0
# outside 198.0
# outside 195.75
# outside 198.0
# outside 195.75
# outside 193.5
# outside 191.25
# outside 198.0
# outside 193.5
# outside 198.0
# outside 195.75
# outside 195.75
# outside 195.75
# outside 193.5
# outside 198.0
# outside 184.5
# outside 186.75
# outside 186.75
# outside 204.75
# outside 173.25
# outside 164.25
# outside 148.5
# outside 173.25
# outside 168.75
# outside 153.0
# outside 155.25
# outside 159.75
# outside 159.75
# outside 141.75
# outside 139.5
# outside 157.5
# outside 139.5
# outside 157.5
# outside 162.0
# outside 150.75
# outside 146.25
# outside 137.25
# outside 148.5
# outside 130.5
# outside 153.0
# outside 164.25
# outside 153.0
# outside 164.25
# outside 162.0
# outside 155.25
# outside 155.25
# outside 166.5
# outside 148.5
# outside 157.5
# outside 157.5
# outside 137.25
# outside 121.5
# outside 137.25
# outside 101.25
# outside 180.0
# outside 157.5
# outside 175.5
# outside 177.75
# outside 186.75
# outside 184.5
# outside 236.25
# outside 13.5
# outside 524.25
# outside 123.75
# outside 148.5
# outside 157.5
# outside 148.5
# outside 146.25
# outside 141.75
# outside 130.5
# outside 135.0
# outside 144.0
# outside 146.25
# outside 139.5
# outside 148.5
# outside 135.0
# outside 108.0
# outside 130.5
# outside 130.5
# outside 128.25
# outside 126.0
# outside 126.0
# outside 128.25
# outside 121.5
# outside 121.5
# outside 128.25
# outside 126.0
# outside 126.0
# outside 121.5
# outside 119.25
# outside 114.75
# outside 112.5
# outside 114.75
# outside 117.0
# outside 110.25
# outside 110.25
# outside 108.0
# outside 114.75
# outside 117.0
# outside 114.75
# outside 114.75
# outside 108.0
# outside 110.25
# outside 108.0
# outside 108.0
# outside 110.25
# outside 108.0
# outside 108.0
# outside 108.0
# outside 105.75
# outside 105.75
# outside 110.25
# outside 105.75
# outside 119.25
# outside 123.75
# outside 99.0
# outside 144.0
# outside 121.5
# outside 128.25
# outside 119.25
# outside 128.25
# outside 112.5
# outside 103.5
# outside 101.25
# outside 132.75
# outside 96.75
# outside 65.25
# outside 263.25
# outside 105.75
# outside 326.25
# outside 135.0
# outside 186.75
# outside 193.5
# outside 207.0
# outside 189.0
# outside 209.25
# outside 272.25
# outside 240.75
# outside 324.0
# outside 407.25
# outside 297.0
# outside 594.0
# outside 45.0
# outside 31.5
# outside 36.0
# outside 2.25
# outside 27.0
# outside 11.25
# outside 15.75
# outside 13.5
# outside 18.0
# outside 110.25
# outside 231.75
# outside 180.0
# outside 182.25
# outside 54.0
# outside 13.5
# outside 198.0
# outside 598.5
# outside 240.75
# outside 186.75
# outside 184.5
# outside 218.25
# outside 200.25
# outside 216.0
# outside 229.5
# outside 227.25
# outside 229.5
# outside 234.0
# outside 229.5
# outside 234.0
# outside 234.0
# outside 227.25
# outside 234.0
# outside 243.0
# outside 234.0
# outside 234.0
# outside 243.0
# outside 240.75
# outside 236.25
# outside 252.0
# outside 222.75
# outside 218.25
# outside 229.5
# outside 209.25
# outside 211.5
# outside 227.25
# outside 213.75
# outside 211.5
# outside 222.75
# outside 213.75
# outside 211.5
# outside 220.5
# outside 218.25
# outside 218.25
# outside 218.25
# outside 213.75
# outside 198.0
# outside 204.75
# outside 189.0
# outside 180.0
# outside 159.75
# outside 146.25
# outside 128.25
# outside 121.5
# outside 128.25
# outside 90.0
# outside 65.25
# outside 45.0
# outside 49.5
# outside 36.0
# outside 38.25
# outside 40.5
# outside 47.25
# outside 92.25
# outside 213.75
# outside 231.75
# outside 234.0
# outside 238.5
# outside 234.0
# outside 229.5
# outside 227.25
# outside 220.5
# outside 186.75
# outside 146.25
# outside 117.0
# outside 103.5
# outside 60.75
# outside 63.0
# outside 139.5
# outside 173.25
# outside 182.25
# outside 182.25
# outside 191.25
# outside 182.25
# outside 166.5
# outside 153.0
# outside 146.25
# outside 90.0
# outside 47.25
# outside 65.25
# outside 207.0
# outside 211.5
# outside 209.25
# outside 207.0
# outside 209.25
# outside 211.5
# outside 218.25
# outside 218.25
# outside 222.75
# outside 218.25
# outside 216.0
# outside 216.0
# outside 220.5
# outside 220.5
# outside 236.25
# outside 234.0
# outside 238.5
# outside 238.5
# outside 234.0
# outside 238.5
# outside 236.25
# outside 238.5
# outside 238.5
# outside 234.0
# outside 240.75
# outside 236.25
# outside 249.75
# outside 254.25
# outside 254.25
# outside 252.0
# outside 240.75
# outside 193.5
# outside 195.75
# outside 141.75
# outside 135.0
# outside 121.5
# outside 114.75
# outside 108.0
# outside 132.75
# outside 204.75
# outside 193.5
# outside 211.5
# outside 222.75
# outside 238.5
# outside 231.75
# outside 229.5
# outside 236.25
# outside 227.25
# outside 234.0
# outside 220.5
# outside 209.25
# outside 222.75
# outside 209.25
# outside 209.25
# outside 200.25
# outside 198.0
# outside 177.75
# outside 184.5
# outside 186.75
# outside 182.25
# outside 180.0
# outside 191.25
# outside 202.5
# outside 193.5
# outside 209.25
# outside 222.75
# outside 231.75
# outside 209.25
# outside 216.0
# outside 218.25
# outside 216.0
# outside 209.25
# outside 200.25
# outside 218.25
# outside 225.0
# outside 191.25
# outside 195.75
# outside 108.0
# outside 227.25
# outside 180.0
# outside 180.0
# outside 193.5
# outside 150.75
# outside 162.0
# outside 171.0
# outside 180.0
# outside 200.25
# outside 191.25
# outside 193.5
